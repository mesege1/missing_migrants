# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
missing = pd.read_csv("data/missingmigrants.csv", encoding='ISO-8859-1')

# %%
missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13020 entries, 0 to 13019
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ï»¿"Main ID"                         13020 non-null  object
#  1   Incident ID                          13020 non-null  object
#  2   Incident Type                        13020 non-null  object
#  3   Region of Incident                   13020 non-null  object
#  4   Website Date                         13005 non-null  object
#  5   Incident year                        13020 non-null  int64
#  6   Reported Month                       13020 non-null  object
#  7   Number of Dead                       12452 non-null  float64
#  8   Minimum Estimated Number of Missing  1311 non-null   float64
#  9   Total Number of Dead and Missing     13020 non-null  int64
#  10  Number of Survivors                  2093 non-null   float64
# ...

# %%
missing_working = missing.drop(columns=['ï»¿"Main ID"', 'Incident ID', 'Information Source', 'URL', 'Source Quality', 'UNSD Geographical Grouping'])

# %%
missing_working.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13020 entries, 0 to 13019
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Incident Type                        13020 non-null  object
#  1   Region of Incident                   13020 non-null  object
#  2   Website Date                         13005 non-null  object
#  3   Incident year                        13020 non-null  int64
#  4   Reported Month                       13020 non-null  object
#  5   Number of Dead                       12452 non-null  float64
#  6   Minimum Estimated Number of Missing  1311 non-null   float64
#  7   Total Number of Dead and Missing     13020 non-null  int64
#  8   Number of Survivors                  2093 non-null   float64
#  9   Number of Females                    2343 non-null   float64
#  10  Number of Males                      8016 non-null   float64
# ...

# %%
missing_cleaned = missing_working.dropna()
missing_cleaned.head(3)
# Out:
#     Incident Type Region of Incident Website Date  Incident year  \
# 44       Incident      Mediterranean   2014-03-18           2014
# 84       Incident      Mediterranean   2014-05-12           2014
# 138      Incident      Mediterranean   2014-07-11           2014
#
#     Reported Month  Number of Dead  Minimum Estimated Number of Missing  \
# 44           March             7.0                                  2.0
# 84             May            17.0                                200.0
# 138           July             4.0                                 21.0
#
#      Total Number of Dead and Missing  Number of Survivors  Number of Females  \
# 44                                  9                  8.0                1.0
# 84                                217                226.0               12.0
# 138                                25                 13.0                1.0
#
#      Number of Males  Number of Children        Region of Origin  \
# ...

# %%
missing_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 44 to 12550
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Incident Type                        49 non-null     object
#  1   Region of Incident                   49 non-null     object
#  2   Website Date                         49 non-null     object
#  3   Incident year                        49 non-null     int64
#  4   Reported Month                       49 non-null     object
#  5   Number of Dead                       49 non-null     float64
#  6   Minimum Estimated Number of Missing  49 non-null     float64
#  7   Total Number of Dead and Missing     49 non-null     int64
#  8   Number of Survivors                  49 non-null     float64
#  9   Number of Females                    49 non-null     float64
#  10  Number of Males                      49 non-null     float64
# ...

# %%
numerical_columns = ['Incident year', 'Number of Dead', 'Minimum Estimated Number of Missing',
                     'Total Number of Dead and Missing', 'Number of Survivors', 'Number of Females',
                     'Number of Males', 'Number of Children']

# %%
sns.pairplot(missing_cleaned[numerical_columns])
